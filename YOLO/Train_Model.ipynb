# %% [markdown]
# # Yolo v7 - Train

# %%
# !pip install -q tensorboard

# %%
import time
from numba import cuda

# %%
device = cuda.get_current_device()
device.reset()

# %%
start_time = time.time()

# %%
# !python train.py --weights yolov7.pt --data "data/pothole.yaml" --workers 4 --batch-size 48 --img 300 --cfg cfg/training/yolov7.yaml --name yolov7_pothole --hyp data/hyp.scratch.p5.yaml --save_period 30
# Out:
# YOLOR 🚀 v0.1-121-g2fdc7f1 torch 1.7.1 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=48, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7.yaml', data='data/pothole.yaml', device='', entity=None, epochs=300, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='data/hyp.scratch.p5.yaml', image_weights=False, img_size=[300, 300], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='yolov7_pothole', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yolov7_pothole', save_period=30, single_cls=False, sync_bn=False, total_batch_size=48, upload_dataset=False, v5_metric=False, weights='yolov7.pt', workers=4, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
print("--- Treinamento finalizado em %s segundos ---" % (time.time() - start_time))
